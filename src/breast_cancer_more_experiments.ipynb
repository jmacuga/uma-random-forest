# %%
from datasets.breast_cancer import BreastCancerDataset
from random_forest import RandomForestClassifier, TournamentRandomForestClassifier
import math, time
from utils.experiments import grid_search

# %%
path = "../data/breast-cancer/breast-cancer.csv"
dataset_name = "breast_koniec"
n_calls = 1

dataset = BreastCancerDataset()
dataset.clean()
X_train, X_val, y_train, y_val = dataset.split(test_size=0.2, random_state=42)

n_features = round(math.sqrt(X_train.shape[1]))

# %%
params_matrix = {
    "n_trees": [30],
    "max_depth": [50],
    "tournament_size": [3],
    "max_features": [n_features],
}

# %%
time_start = time.time()
path = f"../out/breast_cancer/tournament_forest_classifier.csv"
best_params, score, all_results = grid_search(
    params_matrix,
    TournamentRandomForestClassifier,
    X_train,
    X_val,
    y_train,
    y_val,
    n_calls,
    path=path
)

print(f"Execution time: {time.time() - time_start}")
print(f"Best params: {best_params}")
print(f"Best score: {score}")
print(f"All results: {all_results}")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]INFO:root:RandomForestClassifier: n_trees=30, max_depth=50
# INFO:root:TournamentRandomForestClassifier: n_trees=30, max_depth=50, tournament_size=3
# INFO:root:TournamentDecisionTreeClassifier(max_depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=9) created
# INFO:root:Node(split_feature=None, split_val=None, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=12, split_val=12.7295, depth=14) created
# INFO:root:Node(split_feature=21, split_val=18.445, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=0, split_val=14.675, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=25, split_val=0.1598, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=26, split_val=0.28045, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=9, split_val=0.058435, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=9, split_val=0.05756, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=23, split_val=665.1, depth=45) created
# INFO:root:Node(split_feature=18, split_val=0.01079, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=12, split_val=2.936, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=11, split_val=0.4335, depth=49) created
# INFO:root:Node(split_feature=1, split_val=11.05, depth=48) created
# INFO:root:Node(split_feature=7, split_val=0.011325, depth=47) created
# INFO:root:Node(split_feature=3, split_val=283.85, depth=46) created
# INFO:root:Node(split_feature=20, split_val=11.08, depth=45) created
# INFO:root:Node(split_feature=29, split_val=0.063745, depth=44) created
# INFO:root:Node(split_feature=18, split_val=0.011304999999999999, depth=43) created
# INFO:root:Node(split_feature=16, split_val=0.0054855, depth=42) created
# INFO:root:Node(split_feature=20, split_val=10.885, depth=41) created
# INFO:root:Node(split_feature=3, split_val=263.65, depth=40) created
# INFO:root:Node(split_feature=11, split_val=0.37495, depth=39) created
# INFO:root:Node(split_feature=1, split_val=10.600000000000001, depth=38) created
# INFO:root:Node(split_feature=19, split_val=0.0015370000000000002, depth=37) created
# INFO:root:Node(split_feature=15, split_val=0.0070185, depth=36) created
# INFO:root:Node(split_feature=19, split_val=0.0014265, depth=35) created
# INFO:root:Node(split_feature=13, split_val=10.295, depth=34) created
# INFO:root:Node(split_feature=22, split_val=67.055, depth=33) created
# INFO:root:Node(split_feature=29, split_val=0.06128, depth=32) created
# INFO:root:Node(split_feature=8, split_val=0.1252, depth=31) created
# INFO:root:Node(split_feature=27, split_val=0.036945000000000006, depth=30) created
# INFO:root:Node(split_feature=7, split_val=0.010735000000000001, depth=29) created
# INFO:root:Node(split_feature=22, split_val=66.15, depth=28) created
# INFO:root:Node(split_feature=7, split_val=0.01057, depth=27) created
# INFO:root:Node(split_feature=17, split_val=0.0051515, depth=26) created
# INFO:root:Node(split_feature=17, split_val=0.0047405, depth=25) created
# INFO:root:Node(split_feature=26, split_val=0.02279, depth=24) created
# INFO:root:Node(split_feature=14, split_val=0.0028764999999999997, depth=23) created
# INFO:root:Node(split_feature=27, split_val=0.026295, depth=22) created
# INFO:root:Node(split_feature=23, split_val=290.75, depth=21) created
# INFO:root:Node(split_feature=1, split_val=10.045000000000002, depth=20) created
# INFO:root:Node(split_feature=7, split_val=0.008421999999999999, depth=19) created
# INFO:root:Node(split_feature=7, split_val=0.006049, depth=18) created
# INFO:root:Node(split_feature=24, split_val=0.09067, depth=17) created
# INFO:root:Node(split_feature=25, split_val=0.061619999999999994, depth=16) created
# INFO:root:Node(split_feature=14, split_val=0.002852, depth=15) created
# INFO:root:Node(split_feature=25, split_val=0.051989999999999995, depth=14) created
# INFO:root:Node(split_feature=7, split_val=0.00384, depth=13) created
# INFO:root:Node(split_feature=29, split_val=0.059730000000000005, depth=12) created
# INFO:root:Node(split_feature=3, split_val=232.75, depth=11) created
# INFO:root:Node(split_feature=5, split_val=0.035140000000000005, depth=10) created
# INFO:root:Node(split_feature=13, split_val=7.824, depth=9) created
# INFO:root:Node(split_feature=28, split_val=0.16065000000000002, depth=8) created
# INFO:root:Node(split_feature=12, split_val=0.95155, depth=7) created
# INFO:root:Node(split_feature=3, split_val=212.60000000000002, depth=6) created
# INFO:root:Node(split_feature=26, split_val=0.002713, depth=5) created
# INFO:root:Node(split_feature=9, split_val=0.051809999999999995, depth=4) created
# INFO:root:Node(split_feature=19, split_val=0.0010041, depth=3) created
# INFO:root:Node(split_feature=4, split_val=0.06919, depth=2) created
# INFO:root:Node(split_feature=9, split_val=0.050605, depth=1) created
# INFO:root:Node(split_feature=16, split_val=0.000346, depth=0) created
# INFO:root:TournamentDecisionTreeClassifier(max_depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=19.055, depth=4) created
# INFO:root:Node(split_feature=16, split_val=0.015645, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=9) created
# INFO:root:Node(split_feature=None, split_val=None, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=12, split_val=4.8575, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=20, split_val=20.72, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=15, split_val=0.056635000000000005, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=0, split_val=15.155, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=25, split_val=0.21289999999999998, depth=41) created
# INFO:root:Node(split_feature=16, split_val=0.024675000000000002, depth=40) created
# INFO:root:Node(split_feature=28, split_val=0.2233, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=15, split_val=0.02295, depth=46) created
# INFO:root:Node(split_feature=19, split_val=0.0014910000000000001, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=9, split_val=0.053059999999999996, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=6, split_val=0.01117, depth=49) created
# INFO:root:Node(split_feature=3, split_val=340.0, depth=48) created
# INFO:root:Node(split_feature=8, split_val=0.13805, depth=47) created
# INFO:root:Node(split_feature=29, split_val=0.06228499999999999, depth=46) created
# INFO:root:Node(split_feature=13, split_val=11.315, depth=45) created
# INFO:root:Node(split_feature=29, split_val=0.06128, depth=44) created
# INFO:root:Node(split_feature=6, split_val=0.0082325, depth=43) created
# INFO:root:Node(split_feature=8, split_val=0.1363, depth=42) created
# INFO:root:Node(split_feature=3, split_val=306.6, depth=41) created
# INFO:root:Node(split_feature=0, split_val=9.785499999999999, depth=40) created
# INFO:root:Node(split_feature=20, split_val=10.95, depth=39) created
# INFO:root:Node(split_feature=21, split_val=16.785, depth=38) created
# INFO:root:Node(split_feature=19, split_val=0.0011985, depth=37) created
# INFO:root:Node(split_feature=2, split_val=61.269999999999996, depth=36) created
# INFO:root:Node(split_feature=23, split_val=329.85, depth=35) created
# INFO:root:Node(split_feature=1, split_val=12.629999999999999, depth=34) created
# INFO:root:Node(split_feature=11, split_val=0.49575, depth=33) created
# INFO:root:Node(split_feature=25, split_val=0.08573, depth=32) created
# INFO:root:Node(split_feature=29, split_val=0.059525, depth=31) created
# INFO:root:Node(split_feature=11, split_val=0.42635, depth=30) created
# INFO:root:Node(split_feature=26, split_val=0.028805, depth=29) created
# INFO:root:Node(split_feature=28, split_val=0.17855, depth=28) created
# INFO:root:Node(split_feature=27, split_val=0.032185, depth=27) created
# INFO:root:Node(split_feature=8, split_val=0.1264, depth=26) created
# INFO:root:Node(split_feature=12, split_val=0.9597, depth=25) created
# INFO:root:Node(split_feature=25, split_val=0.08107, depth=24) created
# INFO:root:Node(split_feature=25, split_val=0.0774, depth=23) created
# INFO:root:Node(split_feature=7, split_val=0.004378, depth=22) created
# INFO:root:Node(split_feature=2, split_val=60.695, depth=21) created
# INFO:root:Node(split_feature=15, split_val=0.007119, depth=20) created
# INFO:root:Node(split_feature=27, split_val=0.016665, depth=19) created
# INFO:root:Node(split_feature=2, split_val=58.995000000000005, depth=18) created
# INFO:root:Node(split_feature=15, split_val=0.0061985, depth=17) created
# INFO:root:Node(split_feature=10, split_val=0.1357, depth=16) created
# INFO:root:Node(split_feature=1, split_val=10.55, depth=15) created
# INFO:root:Node(split_feature=19, split_val=0.0011065, depth=14) created
# INFO:root:Node(split_feature=25, split_val=0.056459999999999996, depth=13) created
# INFO:root:Node(split_feature=13, split_val=9.385000000000002, depth=12) created
# INFO:root:Node(split_feature=13, split_val=7.276999999999999, depth=11) created
# INFO:root:Node(split_feature=5, split_val=0.03542, depth=10) created
# INFO:root:Node(split_feature=16, split_val=0.00091, depth=9) created
# INFO:root:Node(split_feature=7, split_val=0.003193, depth=8) created
# INFO:root:Node(split_feature=0, split_val=8.802, depth=7) created
# INFO:root:Node(split_feature=5, split_val=0.02883, depth=6) created
# INFO:root:Node(split_feature=2, split_val=54.435, depth=5) created
# INFO:root:Node(split_feature=20, split_val=9.2185, depth=4) created
# INFO:root:Node(split_feature=4, split_val=0.06748, depth=3) created
# INFO:root:Node(split_feature=18, split_val=0.01021, depth=2) created
# INFO:root:Node(split_feature=17, split_val=0.0021190000000000002, depth=1) created
# INFO:root:Node(split_feature=9, split_val=0.050699999999999995, depth=0) created
# INFO:root:TournamentDecisionTreeClassifier(max_depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=17, split_val=0.0062734999999999996, depth=4) created
# INFO:root:Node(split_feature=28, split_val=0.19425, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=9) created
# INFO:root:Node(split_feature=None, split_val=None, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=2, split_val=105.64, depth=18) created
# INFO:root:Node(split_feature=13, split_val=25.56, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=26, split_val=0.46104999999999996, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=17, split_val=0.023613, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=11, split_val=0.66265, depth=26) created
# INFO:root:Node(split_feature=3, split_val=546.3, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=5, split_val=0.04772, depth=37) created
# INFO:root:Node(split_feature=28, split_val=0.19395, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=6, split_val=0.11137, depth=41) created
# INFO:root:Node(split_feature=16, split_val=0.0144915, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=4, split_val=0.07604, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=9, split_val=0.052, depth=49) created
# INFO:root:Node(split_feature=26, split_val=0.051065, depth=48) created
# INFO:root:Node(split_feature=12, split_val=1.0955, depth=47) created
# INFO:root:Node(split_feature=4, split_val=0.07938999999999999, depth=46) created
# INFO:root:Node(split_feature=24, split_val=0.091585, depth=45) created
# INFO:root:Node(split_feature=28, split_val=0.21285, depth=44) created
# INFO:root:Node(split_feature=27, split_val=0.04784, depth=43) created
# INFO:root:Node(split_feature=4, split_val=0.07363, depth=42) created
# INFO:root:Node(split_feature=1, split_val=13.61, depth=41) created
# INFO:root:Node(split_feature=20, split_val=11.415, depth=40) created
# INFO:root:Node(split_feature=29, split_val=0.06128, depth=39) created
# INFO:root:Node(split_feature=29, split_val=0.059789999999999996, depth=38) created
# INFO:root:Node(split_feature=0, split_val=10.082, depth=37) created
# INFO:root:Node(split_feature=1, split_val=12.745000000000001, depth=36) created
# INFO:root:Node(split_feature=25, split_val=0.08107, depth=35) created
# INFO:root:Node(split_feature=1, split_val=12.055, depth=34) created
# INFO:root:Node(split_feature=14, split_val=0.0035269999999999998, depth=33) created
# INFO:root:Node(split_feature=22, split_val=70.985, depth=32) created
# INFO:root:Node(split_feature=7, split_val=0.01129, depth=31) created
# INFO:root:Node(split_feature=15, split_val=0.006627, depth=30) created
# INFO:root:Node(split_feature=14, split_val=0.0032805, depth=29) created
# INFO:root:Node(split_feature=22, split_val=70.495, depth=28) created
# INFO:root:Node(split_feature=2, split_val=61.67, depth=27) created
# INFO:root:Node(split_feature=15, split_val=0.005855, depth=26) created
# INFO:root:Node(split_feature=0, split_val=9.469999999999999, depth=25) created
# INFO:root:Node(split_feature=14, split_val=0.003079, depth=24) created
# INFO:root:Node(split_feature=8, split_val=0.13695000000000002, depth=23) created
# INFO:root:Node(split_feature=12, split_val=0.8851500000000001, depth=22) created
# INFO:root:Node(split_feature=3, split_val=249.6, depth=21) created
# INFO:root:Node(split_feature=27, split_val=0.027055000000000003, depth=20) created
# INFO:root:Node(split_feature=1, split_val=11.355, depth=19) created
# INFO:root:Node(split_feature=20, split_val=9.6975, depth=18) created
# INFO:root:Node(split_feature=3, split_val=231.15, depth=17) created
# INFO:root:Node(split_feature=19, split_val=0.001153, depth=16) created
# INFO:root:Node(split_feature=27, split_val=0.024005, depth=15) created
# INFO:root:Node(split_feature=9, split_val=0.050345, depth=14) created
# INFO:root:Node(split_feature=21, split_val=15.645, depth=13) created
# INFO:root:Node(split_feature=7, split_val=0.0103235, depth=12) created
# INFO:root:Node(split_feature=7, split_val=0.009776, depth=11) created
# INFO:root:Node(split_feature=17, split_val=0.0046825, depth=10) created
# INFO:root:Node(split_feature=26, split_val=0.021085, depth=9) created
# INFO:root:Node(split_feature=13, split_val=7.241, depth=8) created
# INFO:root:Node(split_feature=4, split_val=0.07194500000000001, depth=7) created
# INFO:root:Node(split_feature=27, split_val=0.02037, depth=6) created
# INFO:root:Node(split_feature=27, split_val=0.0125, depth=5) created
# INFO:root:Node(split_feature=15, split_val=0.0042195, depth=4) created
# INFO:root:Node(split_feature=7, split_val=0.003198, depth=3) created
# INFO:root:Node(split_feature=18, split_val=0.01021, depth=2) created
# INFO:root:Node(split_feature=21, split_val=14.51, depth=1) created
# INFO:root:Node(split_feature=7, split_val=0.0026639999999999997, depth=0) created
# INFO:root:TournamentDecisionTreeClassifier(max_depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=24, split_val=0.13565, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=23, split_val=904.95, depth=6) created
# INFO:root:Node(split_feature=5, split_val=0.05996, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=9) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=8, split_val=0.15184999999999998, depth=11) created
# INFO:root:Node(split_feature=12, split_val=1.8285, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=19, split_val=0.001527, depth=49) created
# INFO:root:Node(split_feature=26, split_val=0.051434999999999995, depth=48) created
# INFO:root:Node(split_feature=7, split_val=0.014875, depth=47) created
# INFO:root:Node(split_feature=9, split_val=0.050345, depth=46) created
# INFO:root:Node(split_feature=11, split_val=0.4554, depth=45) created
# INFO:root:Node(split_feature=14, split_val=0.0036815, depth=44) created
# INFO:root:Node(split_feature=5, split_val=0.04987, depth=43) created
# INFO:root:Node(split_feature=14, split_val=0.0032805, depth=42) created
# INFO:root:Node(split_feature=21, split_val=16.060000000000002, depth=41) created
# INFO:root:Node(split_feature=4, split_val=0.07436000000000001, depth=40) created
# INFO:root:Node(split_feature=17, split_val=0.0046825, depth=39) created
# INFO:root:Node(split_feature=6, split_val=0.011345000000000001, depth=38) created
# INFO:root:Node(split_feature=0, split_val=10.795, depth=37) created
# INFO:root:Node(split_feature=24, split_val=0.089065, depth=36) created
# INFO:root:Node(split_feature=13, split_val=12.275, depth=35) created
# INFO:root:Node(split_feature=23, split_val=399.65, depth=34) created
# INFO:root:Node(split_feature=5, split_val=0.047235, depth=33) created
# INFO:root:Node(split_feature=3, split_val=335.95, depth=32) created
# INFO:root:Node(split_feature=25, split_val=0.06475500000000001, depth=31) created
# INFO:root:Node(split_feature=0, split_val=10.052, depth=30) created
# INFO:root:Node(split_feature=10, split_val=0.15195, depth=29) created
# INFO:root:Node(split_feature=3, split_val=301.29999999999995, depth=28) created
# INFO:root:Node(split_feature=0, split_val=9.552, depth=27) created
# INFO:root:Node(split_feature=19, split_val=0.0013075, depth=26) created
# INFO:root:Node(split_feature=23, split_val=323.25, depth=25) created
# INFO:root:Node(split_feature=15, split_val=0.0063135, depth=24) created
# INFO:root:Node(split_feature=3, split_val=273.2, depth=23) created
# INFO:root:Node(split_feature=23, split_val=308.45, depth=22) created
# INFO:root:Node(split_feature=26, split_val=0.02291, depth=21) created
# INFO:root:Node(split_feature=10, split_val=0.12295, depth=20) created
# INFO:root:Node(split_feature=8, split_val=0.13445000000000001, depth=19) created
# INFO:root:Node(split_feature=5, split_val=0.03702, depth=18) created
# INFO:root:Node(split_feature=26, split_val=0.018615, depth=17) created
# INFO:root:Node(split_feature=15, split_val=0.005756, depth=16) created
# INFO:root:Node(split_feature=14, split_val=0.003192, depth=15) created
# INFO:root:Node(split_feature=27, split_val=0.023015, depth=14) created
# INFO:root:Node(split_feature=16, split_val=0.002824, depth=13) created
# INFO:root:Node(split_feature=4, split_val=0.07244500000000001, depth=12) created
# INFO:root:Node(split_feature=8, split_val=0.1338, depth=11) created
# INFO:root:Node(split_feature=11, split_val=0.4053, depth=10) created
# INFO:root:Node(split_feature=25, split_val=0.052315, depth=9) created
# INFO:root:Node(split_feature=25, split_val=0.040255, depth=8) created
# INFO:root:Node(split_feature=26, split_val=0.0066555, depth=7) created
# INFO:root:Node(split_feature=12, split_val=0.8607, depth=6) created
# INFO:root:Node(split_feature=23, split_val=290.1, depth=5) created
# INFO:root:Node(split_feature=14, split_val=0.0029885, depth=4) created
# INFO:root:Node(split_feature=22, split_val=62.31, depth=3) created
# INFO:root:Node(split_feature=17, split_val=0.000926, depth=2) created
# INFO:root:Node(split_feature=11, split_val=0.38045, depth=1) created
# INFO:root:Node(split_feature=23, split_val=259.20000000000005, depth=0) created
# INFO:root:TournamentDecisionTreeClassifier(max_depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=14, split_val=0.005762, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=9) created
# INFO:root:Node(split_feature=None, split_val=None, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=27, split_val=0.044840000000000005, depth=49) created
# INFO:root:Node(split_feature=2, split_val=71.85, depth=48) created
# INFO:root:Node(split_feature=0, split_val=10.83, depth=47) created
# INFO:root:Node(split_feature=7, split_val=0.0105535, depth=46) created
# INFO:root:Node(split_feature=21, split_val=16.375, depth=45) created
# INFO:root:Node(split_feature=3, split_val=341.29999999999995, depth=44) created
# INFO:root:Node(split_feature=22, split_val=72.53999999999999, depth=43) created
# INFO:root:Node(split_feature=26, split_val=0.03493, depth=42) created
# INFO:root:Node(split_feature=2, split_val=64.505, depth=41) created
# INFO:root:Node(split_feature=25, split_val=0.07341500000000001, depth=40) created
# INFO:root:Node(split_feature=3, split_val=295.75, depth=39) created
# INFO:root:Node(split_feature=0, split_val=9.757, depth=38) created
# INFO:root:Node(split_feature=22, split_val=69.065, depth=37) created
# INFO:root:Node(split_feature=6, split_val=0.0097525, depth=36) created
# INFO:root:Node(split_feature=18, split_val=0.01043, depth=35) created
# INFO:root:Node(split_feature=24, split_val=0.08818999999999999, depth=34) created
# INFO:root:Node(split_feature=3, split_val=287.4, depth=33) created
# INFO:root:Node(split_feature=10, split_val=0.14300000000000002, depth=32) created
# INFO:root:Node(split_feature=7, split_val=0.0090515, depth=31) created
# INFO:root:Node(split_feature=5, split_val=0.03936, depth=30) created
# INFO:root:Node(split_feature=16, split_val=0.005353999999999999, depth=29) created
# INFO:root:Node(split_feature=27, split_val=0.023015, depth=28) created
# INFO:root:Node(split_feature=9, split_val=0.0501, depth=27) created
# INFO:root:Node(split_feature=23, split_val=329.4, depth=26) created
# INFO:root:Node(split_feature=21, split_val=15.795, depth=25) created
# INFO:root:Node(split_feature=16, split_val=0.005281, depth=24) created
# INFO:root:Node(split_feature=6, split_val=0.0040285, depth=23) created
# INFO:root:Node(split_feature=22, split_val=65.315, depth=22) created
# INFO:root:Node(split_feature=11, split_val=0.4335, depth=21) created
# INFO:root:Node(split_feature=8, split_val=0.12795, depth=20) created
# INFO:root:Node(split_feature=15, split_val=0.0050865, depth=19) created
# INFO:root:Node(split_feature=17, split_val=0.003157, depth=18) created
# INFO:root:Node(split_feature=11, split_val=0.42295, depth=17) created
# INFO:root:Node(split_feature=13, split_val=9.650500000000001, depth=16) created
# INFO:root:Node(split_feature=23, split_val=305.15, depth=15) created
# INFO:root:Node(split_feature=23, split_val=296.45000000000005, depth=14) created
# INFO:root:Node(split_feature=28, split_val=0.16799999999999998, depth=13) created
# INFO:root:Node(split_feature=0, split_val=8.9585, depth=12) created
# INFO:root:Node(split_feature=6, split_val=0.0015165, depth=11) created
# INFO:root:Node(split_feature=12, split_val=0.8974500000000001, depth=10) created
# INFO:root:Node(split_feature=4, split_val=0.07165, depth=9) created
# INFO:root:Node(split_feature=0, split_val=8.883, depth=8) created
# INFO:root:Node(split_feature=24, split_val=0.08629, depth=7) created
# INFO:root:Node(split_feature=1, split_val=12.280000000000001, depth=6) created
# INFO:root:Node(split_feature=3, split_val=227.7, depth=5) created
# INFO:root:Node(split_feature=21, split_val=13.71, depth=4) created
# INFO:root:Node(split_feature=13, split_val=7.824, depth=3) created
# INFO:root:Node(split_feature=6, split_val=0.0007435, depth=2) created
# INFO:root:Node(split_feature=5, split_val=0.02871, depth=1) created
# INFO:root:Node(split_feature=23, split_val=271.75, depth=0) created
# INFO:root:TournamentDecisionTreeClassifier(max_depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=9) created
# INFO:root:Node(split_feature=None, split_val=None, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=2, split_val=99.945, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=24, split_val=0.14675, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=27, split_val=0.118445, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=10, split_val=0.29195, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=12, split_val=1.6560000000000001, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=2, split_val=69.59, depth=49) created
# INFO:root:Node(split_feature=5, split_val=0.048585, depth=48) created
# INFO:root:Node(split_feature=17, split_val=0.0051515, depth=47) created
# INFO:root:Node(split_feature=20, split_val=11.585, depth=46) created
# INFO:root:Node(split_feature=29, split_val=0.062965, depth=45) created
# INFO:root:Node(split_feature=11, split_val=0.42635, depth=44) created
# INFO:root:Node(split_feature=10, split_val=0.1558, depth=43) created
# INFO:root:Node(split_feature=23, split_val=382.25, depth=42) created
# INFO:root:Node(split_feature=26, split_val=0.04445, depth=41) created
# INFO:root:Node(split_feature=20, split_val=10.975, depth=40) created
# INFO:root:Node(split_feature=1, split_val=12.615, depth=39) created
# INFO:root:Node(split_feature=29, split_val=0.06269, depth=38) created
# INFO:root:Node(split_feature=13, split_val=10.085, depth=37) created
# INFO:root:Node(split_feature=5, split_val=0.047385, depth=36) created
# INFO:root:Node(split_feature=16, split_val=0.004763, depth=35) created
# INFO:root:Node(split_feature=20, split_val=10.754999999999999, depth=34) created
# INFO:root:Node(split_feature=8, split_val=0.1399, depth=33) created
# INFO:root:Node(split_feature=12, split_val=1.0103499999999999, depth=32) created
# INFO:root:Node(split_feature=13, split_val=9.8385, depth=31) created
# INFO:root:Node(split_feature=17, split_val=0.0043595000000000005, depth=30) created
# INFO:root:Node(split_feature=6, split_val=0.0070764999999999995, depth=29) created
# INFO:root:Node(split_feature=0, split_val=9.6675, depth=28) created
# INFO:root:Node(split_feature=26, split_val=0.020110000000000003, depth=27) created
# INFO:root:Node(split_feature=24, split_val=0.093205, depth=26) created
# INFO:root:Node(split_feature=23, split_val=351.75, depth=25) created
# INFO:root:Node(split_feature=27, split_val=0.01746, depth=24) created
# ...
# INFO:root:Node(split_feature=22, split_val=115.95, depth=11) created
# INFO:root:Node(split_feature=12, split_val=1.5585, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=22, split_val=103.28, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=0, split_val=16.765, depth=39) created
# INFO:root:Node(split_feature=4, split_val=0.08507, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=10, split_val=0.7113, depth=45) created
# INFO:root:Node(split_feature=19, split_val=0.0046175, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=8, split_val=0.16449999999999998, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=19, split_val=0.0037715, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=13, split_val=11.495000000000001, depth=49) created
# INFO:root:Node(split_feature=8, split_val=0.13965, depth=48) created
# INFO:root:Node(split_feature=4, split_val=0.06982, depth=47) created
# INFO:root:Node(split_feature=25, split_val=0.08427, depth=46) created
# INFO:root:Node(split_feature=15, split_val=0.0065445, depth=45) created
# INFO:root:Node(split_feature=23, split_val=359.15, depth=44) created
# INFO:root:Node(split_feature=1, split_val=12.835, depth=43) created
# INFO:root:Node(split_feature=13, split_val=11.315, depth=42) created
# INFO:root:Node(split_feature=17, split_val=0.0052885, depth=41) created
# INFO:root:Node(split_feature=0, split_val=9.8155, depth=40) created
# INFO:root:Node(split_feature=7, split_val=0.009222000000000001, depth=39) created
# INFO:root:Node(split_feature=27, split_val=0.024800000000000003, depth=38) created
# INFO:root:Node(split_feature=29, split_val=0.06269, depth=37) created
# INFO:root:Node(split_feature=19, split_val=0.0014464999999999999, depth=36) created
# INFO:root:Node(split_feature=3, split_val=290.0, depth=35) created
# INFO:root:Node(split_feature=9, split_val=0.05136, depth=34) created
# INFO:root:Node(split_feature=16, split_val=0.0042385, depth=33) created
# INFO:root:Node(split_feature=6, split_val=0.0015715, depth=32) created
# INFO:root:Node(split_feature=8, split_val=0.1258, depth=31) created
# INFO:root:Node(split_feature=29, split_val=0.05902, depth=30) created
# INFO:root:Node(split_feature=28, split_val=0.17475, depth=29) created
# INFO:root:Node(split_feature=23, split_val=342.9, depth=28) created
# INFO:root:Node(split_feature=21, split_val=16.165, depth=27) created
# INFO:root:Node(split_feature=13, split_val=9.8385, depth=26) created
# INFO:root:Node(split_feature=18, split_val=0.011945, depth=25) created
# INFO:root:Node(split_feature=12, split_val=1.0162499999999999, depth=24) created
# INFO:root:Node(split_feature=10, split_val=0.1177, depth=23) created
# INFO:root:Node(split_feature=18, split_val=0.0115, depth=22) created
# INFO:root:Node(split_feature=18, split_val=0.011465, depth=21) created
# INFO:root:Node(split_feature=18, split_val=0.01107, depth=20) created
# INFO:root:Node(split_feature=6, split_val=0.0015035, depth=19) created
# INFO:root:Node(split_feature=20, split_val=10.370000000000001, depth=18) created
# INFO:root:Node(split_feature=26, split_val=0.0059375, depth=17) created
# INFO:root:Node(split_feature=3, split_val=271.85, depth=16) created
# INFO:root:Node(split_feature=27, split_val=0.009596, depth=15) created
# INFO:root:Node(split_feature=11, split_val=0.4199, depth=14) created
# INFO:root:Node(split_feature=0, split_val=9.100999999999999, depth=13) created
# INFO:root:Node(split_feature=25, split_val=0.05419, depth=12) created
# INFO:root:Node(split_feature=3, split_val=246.35, depth=11) created
# INFO:root:Node(split_feature=23, split_val=267.1, depth=10) created
# INFO:root:Node(split_feature=11, split_val=0.40225, depth=9) created
# INFO:root:Node(split_feature=19, split_val=0.0012975, depth=8) created
# INFO:root:Node(split_feature=26, split_val=0.002713, depth=7) created
# INFO:root:Node(split_feature=14, split_val=0.002777, depth=6) created
# INFO:root:Node(split_feature=18, split_val=0.010655, depth=5) created
# INFO:root:Node(split_feature=19, split_val=0.00101315, depth=4) created
# INFO:root:Node(split_feature=18, split_val=0.01043, depth=3) created
# INFO:root:Node(split_feature=12, split_val=0.94495, depth=2) created
# INFO:root:Node(split_feature=13, split_val=7.064, depth=1) created
# INFO:root:Node(split_feature=27, split_val=0.004386, depth=0) created
# INFO:root:TournamentDecisionTreeClassifier(max_depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=2, split_val=86.62, depth=3) created
# INFO:root:Node(split_feature=17, split_val=0.018575, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=1, split_val=14.795, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=8) created
# INFO:root:Node(split_feature=None, split_val=None, depth=9) created
# INFO:root:Node(split_feature=None, split_val=None, depth=10) created
# INFO:root:Node(split_feature=None, split_val=None, depth=11) created
# INFO:root:Node(split_feature=None, split_val=None, depth=12) created
# INFO:root:Node(split_feature=None, split_val=None, depth=13) created
# INFO:root:Node(split_feature=None, split_val=None, depth=14) created
# INFO:root:Node(split_feature=None, split_val=None, depth=15) created
# INFO:root:Node(split_feature=None, split_val=None, depth=16) created
# INFO:root:Node(split_feature=None, split_val=None, depth=17) created
# INFO:root:Node(split_feature=None, split_val=None, depth=18) created
# INFO:root:Node(split_feature=None, split_val=None, depth=19) created
# INFO:root:Node(split_feature=None, split_val=None, depth=20) created
# INFO:root:Node(split_feature=None, split_val=None, depth=21) created
# INFO:root:Node(split_feature=None, split_val=None, depth=22) created
# INFO:root:Node(split_feature=None, split_val=None, depth=23) created
# INFO:root:Node(split_feature=None, split_val=None, depth=24) created
# INFO:root:Node(split_feature=None, split_val=None, depth=25) created
# INFO:root:Node(split_feature=None, split_val=None, depth=26) created
# INFO:root:Node(split_feature=None, split_val=None, depth=27) created
# INFO:root:Node(split_feature=None, split_val=None, depth=28) created
# INFO:root:Node(split_feature=None, split_val=None, depth=29) created
# INFO:root:Node(split_feature=None, split_val=None, depth=30) created
# INFO:root:Node(split_feature=None, split_val=None, depth=31) created
# INFO:root:Node(split_feature=None, split_val=None, depth=32) created
# INFO:root:Node(split_feature=None, split_val=None, depth=33) created
# INFO:root:Node(split_feature=None, split_val=None, depth=34) created
# INFO:root:Node(split_feature=None, split_val=None, depth=35) created
# INFO:root:Node(split_feature=None, split_val=None, depth=36) created
# INFO:root:Node(split_feature=None, split_val=None, depth=37) created
# INFO:root:Node(split_feature=None, split_val=None, depth=38) created
# INFO:root:Node(split_feature=None, split_val=None, depth=39) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=0, split_val=11.165, depth=40) created
# INFO:root:Node(split_feature=None, split_val=None, depth=41) created
# INFO:root:Node(split_feature=None, split_val=None, depth=42) created
# INFO:root:Node(split_feature=None, split_val=None, depth=43) created
# INFO:root:Node(split_feature=None, split_val=None, depth=44) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=12, split_val=1.5554999999999999, depth=45) created
# INFO:root:Node(split_feature=None, split_val=None, depth=46) created
# INFO:root:Node(split_feature=None, split_val=None, depth=47) created
# INFO:root:Node(split_feature=None, split_val=None, depth=48) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=29, split_val=0.06364, depth=49) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=None, split_val=None, depth=50) created
# INFO:root:Node(split_feature=15, split_val=0.0090715, depth=49) created
# INFO:root:Node(split_feature=5, split_val=0.0498, depth=48) created
# INFO:root:Node(split_feature=5, split_val=0.044195, depth=47) created
# INFO:root:Node(split_feature=3, split_val=285.4, depth=46) created
# INFO:root:Node(split_feature=2, split_val=63.475, depth=45) created
# INFO:root:Node(split_feature=19, split_val=0.0014030000000000002, depth=44) created
# INFO:root:Node(split_feature=10, split_val=0.1725, depth=43) created
# INFO:root:Node(split_feature=21, split_val=16.295, depth=42) created
# INFO:root:Node(split_feature=15, split_val=0.008839, depth=41) created
# INFO:root:Node(split_feature=28, split_val=0.18565, depth=40) created
# INFO:root:Node(split_feature=25, split_val=0.08107, depth=39) created
# INFO:root:Node(split_feature=4, split_val=0.07533999999999999, depth=38) created
# INFO:root:Node(split_feature=7, split_val=0.0093235, depth=37) created
# INFO:root:Node(split_feature=29, split_val=0.05902, depth=36) created
# INFO:root:Node(split_feature=25, split_val=0.065095, depth=35) created
# INFO:root:Node(split_feature=18, split_val=0.010759999999999999, depth=34) created
# INFO:root:Node(split_feature=15, split_val=0.007464999999999999, depth=33) created
# INFO:root:Node(split_feature=7, split_val=0.006370499999999999, depth=32) created
# INFO:root:Node(split_feature=17, split_val=0.004051, depth=31) created
# INFO:root:Node(split_feature=13, split_val=11.705, depth=30) created
# INFO:root:Node(split_feature=15, split_val=0.005873, depth=29) created
# INFO:root:Node(split_feature=5, split_val=0.03393, depth=28) created
# INFO:root:Node(split_feature=6, split_val=0.0022884999999999997, depth=27) created
# INFO:root:Node(split_feature=0, split_val=9.637, depth=26) created
# INFO:root:Node(split_feature=24, split_val=0.091585, depth=25) created
# INFO:root:Node(split_feature=4, split_val=0.073635, depth=24) created
# INFO:root:Node(split_feature=1, split_val=12.77, depth=23) created
# INFO:root:Node(split_feature=11, split_val=0.45465, depth=22) created
# INFO:root:Node(split_feature=2, split_val=60.44, depth=21) created
# INFO:root:Node(split_feature=22, split_val=67.555, depth=20) created
# INFO:root:Node(split_feature=3, split_val=262.45, depth=19) created
# INFO:root:Node(split_feature=10, split_val=0.14905000000000002, depth=18) created
# INFO:root:Node(split_feature=4, split_val=0.07194500000000001, depth=17) created
# INFO:root:Node(split_feature=24, split_val=0.08843000000000001, depth=16) created
# INFO:root:Node(split_feature=12, split_val=1.189, depth=15) created
# INFO:root:Node(split_feature=10, split_val=0.14484999999999998, depth=14) created
# INFO:root:Node(split_feature=25, split_val=0.05282, depth=13) created
# INFO:root:Node(split_feature=20, split_val=9.632, depth=12) created
# INFO:root:Node(split_feature=27, split_val=0.009941, depth=11) created
# INFO:root:Node(split_feature=13, split_val=9.2815, depth=10) created
# INFO:root:Node(split_feature=14, split_val=0.002832, depth=9) created
# INFO:root:Node(split_feature=9, split_val=0.050345, depth=8) created
# INFO:root:Node(split_feature=19, split_val=0.0009224999999999999, depth=7) created
# INFO:root:Node(split_feature=0, split_val=8.408, depth=6) created
# INFO:root:Node(split_feature=1, split_val=10.9, depth=5) created
# INFO:root:Node(split_feature=11, split_val=0.3846, depth=4) created
# INFO:root:Node(split_feature=5, split_val=0.026625, depth=3) created
# INFO:root:Node(split_feature=15, split_val=0.0033610000000000003, depth=2) created
# INFO:root:Node(split_feature=28, split_val=0.16820000000000002, depth=1) created
# INFO:root:Node(split_feature=2, split_val=52.49, depth=0) created
# 100%|██████████| 1/1 [01:24<00:00, 84.07s/it]
# Execution time: 84.07517194747925
# Best params: {'n_trees': 30, 'max_depth': 50, 'tournament_size': 3, 'max_features': 5}
# Best score: 0.7368421052631579
# All results: [{'n_trees': 30, 'max_depth': 50, 'tournament_size': 3, 'max_features': 5, 'accuracy': 0.7368421052631579, 'precision': 1.0, 'recall': 0.5774647887323944, 'f1': 0.7321428571428571}]
