# %%
import importlib
import tree
import random_forest

importlib.reload(tree)
importlib.reload(random_forest)
# Out:
# <module 'random_forest' from '/home/user/uma-random-forest/src/random_forest.py'>

# %%
from datasets.mushrooms import MushroomDataset
from random_forest import RandomForestClassifier, TournamentRandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay,f1_score, precision_score, recall_score
import math, time
from tqdm import tqdm
import numpy as np

# %% [markdown]
# # Load dataset

# %%
path = "../data/mushroom/agaricus-lepiota.data"
dataset = MushroomDataset(path=path)
dataset.clean()
X_train, X_val, y_train, y_val = dataset.split(test_size=0.2, random_state=42)

# %%
n_features = round(math.sqrt(X_train.shape[1]))

# %% [markdown]
# # Random forest classifier

# %%
params_matrix = {
    "n_trees": [100, 200, 300],
    "max_depth": [3, 5, 7],
    "max_features": [n_features],
}

# %%
from utils import experiments
importlib.reload(experiments)
from utils.experiments import grid_search  

n_calls = 10

best_params, score, all_results  = grid_search(params_matrix, RandomForestClassifier, X_train, X_val, y_train, y_val, n_calls)
print(f"Best params: {best_params}")
print(f"Best score: {score}")
print(f"All rEsults: {all_results}")
# Out:
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=13, split_val=2.5, depth=1) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=2) created
# INFO:root:Node(split_feature=19, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=5.75, depth=2) created
# INFO:root:Node(split_feature=13, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=8, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=14, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=16, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=6.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=17, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=16, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=18, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=17, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=16, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=21, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=6.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=14, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=17, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=2.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=2, split_val=4.5, depth=1) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=6.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=11, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=14, split_val=6.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=19, split_val=1.25, depth=1) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=19, split_val=5.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=6.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=5.0, depth=2) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=13, split_val=2.5, depth=1) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=5.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=9.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=16, split_val=2.5, depth=2) created
# INFO:root:Node(split_feature=16, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=16, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=2.5, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.75, depth=2) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=6.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=6.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=21, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# ...
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=14, split_val=3.5, depth=6) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=5) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.25, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=18, split_val=1.25, depth=6) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=6) created
# INFO:root:Node(split_feature=8, split_val=2.75, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=18, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=21, split_val=3.25, depth=3) created
# INFO:root:Node(split_feature=0, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=2, split_val=1.5, depth=5) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=6) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=8, split_val=2.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=19, split_val=1.0, depth=6) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=2, split_val=3.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=12, split_val=1.25, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=5) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=2, split_val=6.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=13, split_val=3.0, depth=6) created
# INFO:root:Node(split_feature=14, split_val=2.75, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=11, split_val=1.75, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=21, split_val=4.75, depth=6) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=5.75, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=8, split_val=2.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=9, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=6) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=21, split_val=5.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=5) created
# INFO:root:Node(split_feature=21, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=17, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=16, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=16, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=8, split_val=9.0, depth=2) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=11, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=21, split_val=5.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=0, split_val=4.0, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=6) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=5) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=6) created
# INFO:root:Node(split_feature=8, split_val=1.0, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=2, split_val=6.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=5) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=2, split_val=5.0, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=5.75, depth=4) created
# INFO:root:Node(split_feature=21, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# Best params: {'n_trees': 100, 'max_depth': 5, 'max_features': 5}
# Accuracy: 0.8516923076923076

# %% [markdown]
# ## Wyniki
#
# params_matrix = {
#     "n_trees": [100, 200, 300],
#     "max_depth": [3, 5, 7],
#     "max_features": [n_features],
# }
#
# wyniki:
#
# Best params: {'n_trees': 100, 'max_depth': 5, 'max_features': 5}
# Accuracy: 0.8516923076923076
#
# Num of test samples: 1625
# Accuracy: 0.7956923076923077
# Precission: 0.7174468085106382
# Recall: 1.0
# F1: 0.8354806739345887

# %%
best_params = {'n_trees': 100, 'max_depth': 5, 'max_features': 5}

# %%
accuracy_arr, precision_arr, recall_arr, f1_arr = [], [], [], []
for i in tqdm(range(n_calls)):
    rf = RandomForestClassifier(**best_params)
    rf.fit(X_train, y_train)
    y_preds = [rf.predict(x) for x in X_val]

    accuracy = accuracy_score(y_val, y_preds)
    precission = precision_score(y_val, y_preds)
    recall = recall_score(y_val, y_preds)
    f1 = f1_score(y_val, y_preds)
    accuracy_arr.append(accuracy)
    precision_arr.append(precission)
    recall_arr.append(recall)
    f1_arr.append(f1)

accuracy = np.mean(accuracy_arr)
precission = np.mean(precision_arr)
recall = np.mean(recall_arr)
f1 = np.mean(f1_arr)


print("Random forest:\n")
print("Num of test samples: " + str(len(X_val)))
print(f"Accuracy: {accuracy}")
print(f"Precission: {precission}")
print(f"Recall: {recall}")
print(f"F1: {f1}")
conf_matix = ConfusionMatrixDisplay(confusion_matrix(y_val, y_preds))
# Out:
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=2.25, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=2.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=7, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=5.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=14, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=17, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=8, split_val=4.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=18, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=0, split_val=1.75, depth=4) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=4.75, depth=4) created
# INFO:root:Node(split_feature=14, split_val=1.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=4) created
# INFO:root:Node(split_feature=13, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=19, split_val=5.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=14, split_val=6.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=13, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=5.5, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=20, split_val=2.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=13, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=5.75, depth=3) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=4) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=18, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=5.0, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=17, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=19, split_val=2.25, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=2.25, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=9, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=14, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=17, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=19, split_val=1.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=14, split_val=2.25, depth=3) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=14, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=4.75, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=6.0, depth=2) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=16, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=1) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=4) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=2, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=14, split_val=1.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=2.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=7.25, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=2, split_val=3.25, depth=3) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=16, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=7.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=6.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=4.75, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=3) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=5.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=21, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=7.0, depth=4) created
# INFO:root:Node(split_feature=8, split_val=9.0, depth=3) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=2) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=10, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=19, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=14, split_val=3.25, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=19, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=21, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=7.25, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=9.75, depth=3) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=13, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=2) created
# INFO:root:Node(split_feature=12, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=4.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=4) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=4) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=6.0, depth=4) created
# INFO:root:Node(split_feature=13, split_val=2.25, depth=3) created
# INFO:root:Node(split_feature=21, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=16, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=14, split_val=2.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=7.0, depth=3) created
# INFO:root:Node(split_feature=16, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=2) created
# ...
# INFO:root:Node(split_feature=2, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=4.75, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=2.5, depth=4) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=14, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=18, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=13, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=14, split_val=3.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=9.75, depth=3) created
# INFO:root:Node(split_feature=8, split_val=7.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=1.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=4, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=2) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=2.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=21, split_val=2.75, depth=1) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=14, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=13, split_val=1.75, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=16, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=2, split_val=1.5, depth=3) created
# INFO:root:Node(split_feature=3, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=13, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=8, split_val=5.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=4) created
# INFO:root:Node(split_feature=10, split_val=1.75, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=2) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=1) created
# INFO:root:Node(split_feature=20, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=12, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=3.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=4.25, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=8, split_val=4.75, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=17, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=11, split_val=1.75, depth=2) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=11, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=21, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=5.0, depth=2) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=20, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=8, split_val=4.0, depth=1) created
# INFO:root:Node(split_feature=12, split_val=2.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=1.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=6.0, depth=4) created
# INFO:root:Node(split_feature=19, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=2, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=2, split_val=2.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=4, split_val=3.0, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=0, split_val=1.25, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=19, split_val=1.5, depth=2) created
# INFO:root:Node(split_feature=4, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=3.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=1.0, depth=4) created
# INFO:root:Node(split_feature=19, split_val=2.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=10, split_val=3.0, depth=4) created
# INFO:root:Node(split_feature=1, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=4, split_val=4.25, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=4.0, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=2.0, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=13, split_val=3.0, depth=3) created
# INFO:root:Node(split_feature=1, split_val=1.0, depth=2) created
# INFO:root:Node(split_feature=13, split_val=1.0, depth=1) created
# INFO:root:Node(split_feature=10, split_val=1.0, depth=0) created
# Random forest:
#
# Num of test samples: 1625
# Accuracy: 0.7956923076923077
# Precission: 0.7174468085106382
# Recall: 1.0
# F1: 0.8354806739345887

# %% [markdown]
# # Tournament Random forest

# %%
params_matrix = {
    "n_trees": [100, 200, 300],
    "max_depth": [3, 5, 7],
    "tournament_size": [3, 5, 7],
    "max_features": [n_features],
}

# %%
import importlib
from utils import experiments

importlib.reload(experiments)
from utils.experiments import grid_search

n_calls = 10

best_params, score, all_results = grid_search(params_matrix, TournamentRandomForestClassifier, X_train, X_val, y_train, y_val, n_calls)
print(f"Best params: {best_params}")
print(f"Best score: {score}")
print(f"All rEsults: {all_results}")
# Out:
# 100%|██████████| 1/1 [01:26<00:00, 86.28s/it]
# Best params: {'n_trees': 10, 'max_depth': 5, 'tournament_size': 7, 'max_features': 5}
# Best score: 0.6236307692307693
# All rEsults: [{'n_trees': 10, 'max_depth': 5, 'tournament_size': 7, 'max_features': 5, 'accuracy': 0.6236307692307693, 'precision': 0.584507137486008, 'recall': 1.0, 'f1': 0.7362310462544407}]

# %% [markdown]
# ## Wyniki
#
# All rEsults: [{'n_trees': 10, 'max_depth': 5, 'tournament_size': 7, 'max_features': 5, 'accuracy': 0.6236307692307693, 'precision': 0.584507137486008, 'recall': 1.0, 'f1': 0.7362310462544407}]

# %%
accuracy_arr, precision_arr, recall_arr, f1_arr = [], [], [], []
for i in tqdm(range(n_calls)):
    trf = TournamentRandomForestClassifier(**best_params)
    trf.fit(X_train, y_train)
    y_preds = [trf.predict(x) for x in X_val]

    accuracy = accuracy_score(y_val, y_preds)
    precission = precision_score(y_val, y_preds)
    recall = recall_score(y_val, y_preds)
    f1 = f1_score(y_val, y_preds)
    accuracy_arr.append(accuracy)
    precision_arr.append(precission)
    recall_arr.append(recall)
    f1_arr.append(f1)

accuracy = np.mean(accuracy_arr)
precission = np.mean(precision_arr)
recall = np.mean(recall_arr)
f1 = np.mean(f1_arr)


print("Num of test samples: " + str(len(X_val)))
print(f"Accuracy: {accuracy}")
print(f"Precission: {precission}")
print(f"Recall: {recall}")
print(f"F1: {f1}")
# Out:
# 100%|██████████| 10/10 [00:42<00:00,  4.28s/it]
# Num of test samples: 1625
# Accuracy: 0.5828923076923077
# Precission: 0.5574699562731642
# Recall: 1.0
# F1: 0.7149059271888879
