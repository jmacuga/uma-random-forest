# %%
import importlib
import tree
import random_forest

importlib.reload(tree)
importlib.reload(random_forest)
# Out:
# <module 'random_forest' from '/home/julia/uma-random-forest/src/random_forest.py'>

# %%
from datasets.mushrooms import MushroomDataset
from random_forest import RandomForestClassifier, TournamentRandomForestClassifier
import math, time
from utils.experiments import grid_search

# %% [markdown]
# # Load dataset

# %%
path = "../data/mushroom/agaricus-lepiota.data"
dataset = MushroomDataset(path=path)
dataset.clean()
X_train, X_val, y_train, y_val = dataset.split(test_size=0.2, random_state=42)

# %%
n_features = round(math.sqrt(X_train.shape[1]))

# %% [markdown]
# # Random forest classifier

# %%
params_matrix = {
    "n_trees": [100, 200, 300],
    "max_depth": [
        3, 5, 7
    ],
    "max_split_values" : [1000],
    "max_features": [n_features],
}

# %%
save_path = "../out/mushrooms/random_forest_classifier.csv"
n_calls = 1
time_start = time.time()
best_params, score, all_results = grid_search(
    params_matrix, RandomForestClassifier, X_train, X_val, y_train, y_val, n_calls, path = save_path
)
print(f"Execution time: {time.time() - time_start}")
print(f"Best params: {best_params}")
print(f"Best score: {score}")
print(f"All rEsults: {all_results}")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]INFO:root:RandomForestClassifier: n_trees=10, max_depth=3
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=67, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=6, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=107, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=74, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=51, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=96, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=28, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=97, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=97, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=92, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=55, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=96, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=68, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=63, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=28, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=51, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=23, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=54, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=42, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=59, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=114, split_val=0.5, depth=0) created
#   4%|▍         | 1/25 [00:00<00:17,  1.39it/s]INFO:root:RandomForestClassifier: n_trees=10, max_depth=4
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=47, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=111, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=96, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=39, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=97, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=28, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=87, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=29, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=80, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=64, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=79, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=6, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=70, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=51, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=25, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=11, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=113, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=97, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=23, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=111, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=109, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=64, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=111, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=47, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=105, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=70, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=14, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=101, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=79, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=77, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=112, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=54, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=70, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=92, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=109, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=6, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=97, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=115, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=63, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=0, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=30, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=0) created
#   8%|▊         | 2/25 [00:01<00:20,  1.13it/s]INFO:root:RandomForestClassifier: n_trees=10, max_depth=5
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=107, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=80, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=9, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=11, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=60, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=2, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=101, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=88, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=9, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=56, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=110, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=112, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=109, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=23, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=14, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=81, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=113, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=79, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=25, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=111, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=115, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=81, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=107, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=54, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=28, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=106, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=88, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=89, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=47, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=105, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=88, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=96, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=81, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=63, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=6, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=110, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=40, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=22, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=83, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=6, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=110, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=81, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=9, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=63, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=18, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=47, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=60, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=22, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=96, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=60, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=92, split_val=0.5, depth=0) created
#  12%|█▏        | 3/25 [00:02<00:20,  1.05it/s]INFO:root:RandomForestClassifier: n_trees=10, max_depth=6
# INFO:root:DecisionTreeClassifier(max_depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=22, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=19, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=6, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=105, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=112, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=60, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=14, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=97, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=64, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=26, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=88, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=97, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=8, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=104, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=115, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=110, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=17, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=91, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=108, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=54, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=110, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=98, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=28, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=72, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=96, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=52, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=2) created
# ...
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=61, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=114, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=29, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=93, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=115, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=55, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=111, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=92, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=98, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=53, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=10, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=8, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=79, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=28, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=80, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=22, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=110, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=46, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=13, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=25, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=1) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=115, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=94, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=37, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=65, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=14, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=92, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=64, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=5, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=109, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=105, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=15, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=49, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=36, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=22, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=57, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=85, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=71, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=33, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=112, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=58, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=100, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=50, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=0) created
# INFO:root:DecisionTreeClassifier(max_depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=None, split_val=None, depth=7) created
# INFO:root:Node(split_feature=14, split_val=0.5, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=21, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=62, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=111, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=90, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=86, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=56, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=27, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=20, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=34, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=None, split_val=None, depth=6) created
# INFO:root:Node(split_feature=102, split_val=0.5, depth=5) created
# INFO:root:Node(split_feature=None, split_val=None, depth=5) created
# INFO:root:Node(split_feature=93, split_val=0.5, depth=4) created
# INFO:root:Node(split_feature=None, split_val=None, depth=4) created
# INFO:root:Node(split_feature=113, split_val=0.5, depth=3) created
# INFO:root:Node(split_feature=None, split_val=None, depth=3) created
# INFO:root:Node(split_feature=88, split_val=0.5, depth=2) created
# INFO:root:Node(split_feature=None, split_val=None, depth=2) created
# INFO:root:Node(split_feature=24, split_val=0.5, depth=1) created
# INFO:root:Node(split_feature=35, split_val=0.5, depth=0) created
# 100%|██████████| 25/25 [01:11<00:00,  2.88s/it]
# Execution time: 71.89852547645569
# Best params: {'n_trees': 10, 'max_depth': 7, 'max_split_values': 1000, 'max_features': 11}
# Best score: 0.9624615384615385
# All rEsults: [{'n_trees': 10, 'max_depth': 3, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.7341538461538462, 'precision': 0.6611764705882353, 'recall': 1.0, 'f1': 0.7960339943342776}, {'n_trees': 10, 'max_depth': 4, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8763076923076923, 'precision': 0.8074712643678161, 'recall': 1.0, 'f1': 0.8934817170111288}, {'n_trees': 10, 'max_depth': 5, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.827076923076923, 'precision': 0.75, 'recall': 1.0, 'f1': 0.8571428571428571}, {'n_trees': 10, 'max_depth': 6, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8578461538461538, 'precision': 0.7849162011173184, 'recall': 1.0, 'f1': 0.8794992175273866}, {'n_trees': 10, 'max_depth': 7, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.9624615384615385, 'precision': 0.9325221238938053, 'recall': 1.0, 'f1': 0.9650829994275901}, {'n_trees': 20, 'max_depth': 3, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.7987692307692308, 'precision': 0.7205128205128205, 'recall': 1.0, 'f1': 0.8375558867362146}, {'n_trees': 20, 'max_depth': 4, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8867692307692308, 'precision': 0.8208373904576436, 'recall': 1.0, 'f1': 0.9016042780748663}, {'n_trees': 20, 'max_depth': 5, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8535384615384616, 'precision': 0.7798334875115633, 'recall': 1.0, 'f1': 0.8762993762993763}, {'n_trees': 20, 'max_depth': 6, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8566153846153847, 'precision': 0.783457249070632, 'recall': 1.0, 'f1': 0.8785825951016154}, {'n_trees': 20, 'max_depth': 7, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.904, 'precision': 0.8438438438438438, 'recall': 1.0, 'f1': 0.9153094462540716}, {'n_trees': 30, 'max_depth': 3, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.5987692307692307, 'precision': 0.5638795986622074, 'recall': 1.0, 'f1': 0.7211291702309667}, {'n_trees': 30, 'max_depth': 4, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.7809230769230769, 'precision': 0.7030859049207673, 'recall': 1.0, 'f1': 0.8256611165523996}, {'n_trees': 30, 'max_depth': 5, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8547692307692307, 'precision': 0.7812789620018535, 'recall': 1.0, 'f1': 0.8772112382934444}, {'n_trees': 30, 'max_depth': 6, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.7956923076923077, 'precision': 0.7174468085106382, 'recall': 1.0, 'f1': 0.8354806739345887}, {'n_trees': 30, 'max_depth': 7, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.9015384615384615, 'precision': 0.8404785643070788, 'recall': 1.0, 'f1': 0.9133261105092091}, {'n_trees': 40, 'max_depth': 3, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.6215384615384615, 'precision': 0.5781893004115226, 'recall': 1.0, 'f1': 0.7327249022164276}, {'n_trees': 40, 'max_depth': 4, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.5901538461538461, 'precision': 0.558648111332008, 'recall': 1.0, 'f1': 0.7168367346938775}, {'n_trees': 40, 'max_depth': 5, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8467692307692307, 'precision': 0.771978021978022, 'recall': 1.0, 'f1': 0.8713178294573644}, {'n_trees': 40, 'max_depth': 6, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8867692307692308, 'precision': 0.8208373904576436, 'recall': 1.0, 'f1': 0.9016042780748663}, {'n_trees': 40, 'max_depth': 7, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.8867692307692308, 'precision': 0.8208373904576436, 'recall': 1.0, 'f1': 0.9016042780748663}, {'n_trees': 50, 'max_depth': 3, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.5372307692307692, 'precision': 0.5285266457680251, 'recall': 1.0, 'f1': 0.6915504511894995}, {'n_trees': 50, 'max_depth': 4, 'max_split_values': 1000, 'max_features': 11, 'accuracy': 0.5846153846153846, 'precision': 0.5553359 ...

# %% [markdown]
# # Tournament Random forest

# %%
params_matrix = {
    "n_trees": [100, 200, 300],
    "max_depth": [3, 5, 7],
    "tournament_size": [3, 5, 7],
    "max_features": [n_features],
}

# %%
import importlib
from utils import experiments

importlib.reload(experiments)
from utils.experiments import grid_search

n_calls = 10

best_params, score, all_results = grid_search(params_matrix, TournamentRandomForestClassifier, X_train, X_val, y_train, y_val, n_calls)
print(f"Best params: {best_params}")
print(f"Best score: {score}")
print(f"All rEsults: {all_results}")
# Out:
# 100%|██████████| 1/1 [01:26<00:00, 86.28s/it]
# Best params: {'n_trees': 10, 'max_depth': 5, 'tournament_size': 7, 'max_features': 5}
# Best score: 0.6236307692307693
# All rEsults: [{'n_trees': 10, 'max_depth': 5, 'tournament_size': 7, 'max_features': 5, 'accuracy': 0.6236307692307693, 'precision': 0.584507137486008, 'recall': 1.0, 'f1': 0.7362310462544407}]
